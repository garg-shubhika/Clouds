# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\dell\Pictures\LOCUST\Part-1\example_stats_history.csv")
df2= pd.read_csv(r"C:\Users\dell\Pictures\LOCUST\Part-2\example_stats_history.csv")
df3=pd.read_csv(r"C:\Users\dell\Pictures\LOCUST\Part-3\example_stats_history.csv")
df4=pd.read_csv(r"C:\Users\dell\Pictures\LOCUST\Part-4\example_stats_history.csv")

f = plt.figure(figsize=(10,7))
plt.subplot(2, 2, 3)
(df3.iloc[1:,4].plot(label='webapp',color='red'))
plt.title('webapp')
plt.subplot(2, 2, 1)
df.iloc[1:,4].plot(label='local',color='blue')
plt.title('local')
plt.subplot(2,2, 2)
df2.iloc[1:,4].plot(label='scaleset',color='green')
plt.title('scaleset')
plt.subplot(2,2, 4)
df4.iloc[1:,4].plot(label='functionapp',color='purple')
plt.title('functionapp')
f.suptitle('100 users, 3 minutes Locust testing')
plt.show()
